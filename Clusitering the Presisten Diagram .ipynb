# %%
import numpy as np
import pandas as pd
import csv 
from pandas import *
import glob 
import os

# %%
# get a list of all csv files in target directory 


path = "/Users/Esteban/Desktop/GitHub/TDA-MSRI-2018/600_Persistence_Diagrams"

extention = "csv"

os.chdir(path)

PresistenDiagram = [i for i in glob.glob('*.{}'.format(extention))]

PresistenDiagram

Mydata = [0 for x in range(600)]
for i in range(len(PresistenDiagram)):
    Mydata[i] = pd.read_csv("/Users/Esteban/Desktop/GitHub/TDA-MSRI-2018/600_Persistence_Diagrams/"+ str(PresistenDiagram[i]) )

# %%
for j in range (0:3):
    M = Mydata[ Mydata[,2] == j, ]
    if (j == 0){
        Y = hcluster
    }
# Out:
#       Unnamed: 0  Dimension     Birth     Death
# 0              0          0  0.000000  0.583352
# 1              1          0  0.000000  0.594504
# 2              2          0  0.000000  0.595606
# 3              3          0  0.000000  0.597008
# 4              4          0  0.000000  0.618398
# 5              5          0  0.000000  0.634573
# 6              6          0  0.000000  0.836135
# 7              7          0  0.000000  0.847952
# 8              8          0  0.000000  0.856774
# 9              9          0  0.000000  0.857544
# 10            10          0  0.000000  0.860376
# 11            11          0  0.000000  0.861036
# 12            12          0  0.000000  0.862623
# 13            13          0  0.000000  0.863525
# 14            14          0  0.000000  0.864971
# 15            15          0  0.000000  0.871583
# 16            16          0  0.000000  0.873970
# 17            17          0  0.000000  0.880672
# 18            18          0  0.000000  0.910462
# ...
